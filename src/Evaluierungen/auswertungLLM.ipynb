# %%
# Helpers

############################################################################################
# Falls JSON nicht fertig generiert wurde, wird json beim letzten vollständigen Block beendet.
# Gibt Json Objekt zurück
############################################################################################
def fixUnfinishedJson(output):

    import json
    try:
        ojson = json.loads(output)
        return ojson
    except json.decoder.JSONDecodeError:
        lastValidIndex = output.rfind("""}},""")

        lastValidIndex += len("""}},""")-1

        output = output[:lastValidIndex]
        output += """]}"""
        return json.loads(output)
    
############################################################################################
# Filtert aus gesamter KI-Ausgabe (string) die Antowort raus
############################################################################################
def findResponse(output):
    response= "### Response:"
    response_index = output.find(response)
    if response_index == -1:
        return output
    response_index += len(response)
    output = output[response_index:]
    return output

import json
import os
############################################################################################
# Gibt die nächste Versionsnummer zurück
############################################################################################
def get_next_version(fullpath):
    """
    Finds the next version number
    """
    
    # Split the path into directory and filename
    directory, full_file_name = os.path.split(fullpath)
    

    # Check if the directory exists, if not create it and return 0
    if not os.path.exists(directory):
        os.makedirs(directory)

    from pathlib import Path
    file = Path(f"{directory}\\{ID}_.json")
    if file.exists():

        j = json.load(file.open("r"))
        j["v"] = j["v"] + 1
        json.dump(j, file.open("w"))
        return j["v"]
    else:
        j = {"v": 1}
        json.dump(j, file.open("w"))
        return j["v"]

############################################################################################
# Gibt Dateiname und Speicherpfad zurück für organisiertes Speichern der Ergebnisse
############################################################################################
def getFilePath(name="", ext =""):
    return f"""{directory}{ID}_v{VERSION}_{name}{ext}"""

############################################################################################
# Generiert Samples aus Json Objekt
############################################################################################
def generateSamples(hlabsJson):
        import numpy
        sample_rate = 16000
        audio_arr = []

        for block in hlabsJson["sequence"]:
            if block["type"] == "v": # wemm Sinuswelle

                duration_in_seconds = block["data"]["dur"] / 1000
                ampitude = block["data"]["amp"]
                fequencie = block["data"]["freq"]

                t = numpy.linspace(0, duration_in_seconds, int(sample_rate *duration_in_seconds), endpoint=False)  # Time array
                audio_arr.extend(ampitude * numpy.sin(2 * numpy.pi * fequencie * t))  # Sine wave formula

            else: # wenn Pause
                duration_in_seconds = block["data"]["dur"] / 1000
                audio_arr.extend(numpy.zeros(int(sample_rate * duration_in_seconds)))
        return numpy.float32(audio_arr)

############################################################################################
# Visualisiert die Ausgabe (Json Objekt)
############################################################################################
def plotOutput(ojson):
    import matplotlib.pyplot as plt
    import matplotlib.patches as patches

    plt.figure().set_figwidth(20) 

    amplitudes = []
    frequencies = []
    times = []
    times.append(0)
    for block in ojson["sequence"]:
        if block["type"] == "v":
            amplitudes.append(block["data"]["amp"])
            frequencies.append(block["data"]["freq"])
        else:
            amplitudes.append(0)
            frequencies.append(0)
            if len(times) > 0:
                plt.axvspan(times[-1], times[-1] + block["data"]["dur"], color="green", alpha=0.5)
            else:
                plt.axvspan(0, block["data"]["dur"], color="green", alpha=1)
        if len(times) == 0:
            times.append(block["data"]["dur"])
        else:
            times.append(times[-1] + block["data"]["dur"])
    times_block_mid = []
    times_block_mid.append(times[0] - 0 / 2)

       
    line1 =plt.hlines(amplitudes, times[:-1], times[1:], color="blue",label="Amplitude")
    plt.ylabel("Amplitude")
    plt.xlabel("Zeit in Millisekunden")
    plt.legend(loc="upper right")
    plt.twinx()
    line2=plt.hlines(frequencies, times[:-1], times[1:], color="red",label="Frequenz")
    plt.ylabel("Frequenz in Hertz")
    plt.legend(handles=[line1, line2])
    plt.savefig(getFilePath(name="Blocks",ext=".png"))

############################################################################################
# Visualisiert Signal
############################################################################################
def plotOutputSignal(audio_arr):
    import numpy
    import matplotlib.pyplot as plt
    times = numpy.arange(0,len(audio_arr)/16,1/16)
    plt.figure().set_figwidth(20)
    plt.plot(times, audio_arr,label="Signal")
    plt.hlines([-1,1],0,times[-1],colors="red",label="Amplitudengrenzen")
    plt.xlabel("Zeit in Millisekunden")
    plt.legend()
    plt.savefig(getFilePath(name="Signal",ext=".png"))

############################################################################################
# Speichert Signal als wav-Datei
############################################################################################
def saveAsWav(audio_arr, sr):
    import scipy.io.wavfile
    filename = getFilePath(name="",ext=".wav")
    scipy.io.wavfile.write(filename, sr, audio_arr)
    return filename

def visualize(ojson):
    plotOutput(ojson)
    samples=generateSamples(ojson)
    plotOutputSignal(samples)
    # wav-Audio erstellen
    wavFile = saveAsWav(samples, 16000)

    # Audio anzeigen
    from IPython import display
    display.display(display.Audio(wavFile))




ID = "" #Wiedererkennung des Prompts (z.B ID = ID des Datensatzes aus dem der Prompt stammt)
VERSION = -1 #wird durch get_next_version() gesetzt (pro generierter Ausgabe)
directory = "..\\viblib\\colabGenerarions\\"

# %%
def countOfVBlocks(ojson):
    count = 0
    for block in ojson["sequence"]:
        if block["type"] == "v":
            count += 1
    return count
def countOfPBlocks(ojson):
    count = 0
    for block in ojson["sequence"]:
        if block["type"] == "p":
            count += 1
    return count
def pBlockDuration(ojson):
    for block in ojson["sequence"]:
        duration = 0
        if block["type"] == "p":
            duration += block["data"]["dur"]
def meanFrequency(ojson):
    frequencies = []
    durations = []

    for block in ojson["sequence"]:
        if block["type"] == "v":
            dur= block["data"]["dur"]
            freq = block["data"]["freq"]
            frequencies.append(freq)
            durations.append(dur)

    return sum(frequencies*durations)/sum(durations)
def meanAmplitude(ojson):
    amplitudes = []
    durations = []

    for block in ojson["sequence"]:
        if block["type"] == "v":
            dur= block["data"]["dur"]
            amp = block["data"]["amp"]
            amplitudes.append(amp)
            durations.append(dur)

    return sum(amplitudes*durations)/sum(durations)

def standardDeviationAmplitude(json):
    mean = meanAmplitude(ojson)
    
def compareDistribution(refJson,genJson,feature):
    import numpy as np
    from scipy.stats import gaussian_kde
    import matplotlib.pyplot as plt

    refDate = []
    for block in refJson["sequence"]:
        if (feature == "amp" or feature == "freq") and block["type"] == "p":

            refDate.append(0)
        else:
            refDate.append(block["data"][feature])

    genData = []
    for block in genJson["sequence"]:
        if (feature == "amp" or feature == "freq") and block["type"] == "p":
            genData.append(0)
        else:
            genData.append(block["data"][feature])
    
    refKDE = gaussian_kde(refDate)
    genKDE = gaussian_kde(genData)

    # Gemeinsamer Wertebereich für die KDE-Plots
    x_vals = np.linspace(min(min(refDate), min(genData)), max(max(refDate), max(genData)), 1000)

    # Berechnung der Wahrscheinlichkeitsdichte für beide KDEs
    refPDF = refKDE(x_vals)
    genPDF = genKDE(x_vals)

    # plt.figure()
    # plt.plot(x_vals, refPDF, label='Dichtefunktion Referenz', color='blue')
    # plt.plot(x_vals, genPDF, label='Dichtefunktion Generiert', color='red')
    # plt.fill_between(x_vals, np.minimum(refPDF, genPDF), color='purple', alpha=0.5, label='Überlappende Fläche')
    # plt.title('Wahrscheinlichkeitsdichtefunktionen und Überlappung ' + feature)
    # plt.xlabel('Werte')
    # plt.ylabel('Dichte')
    # plt.legend()

    # Berechnung der überlappenden Fläche
    overlap_area = np.trapz(np.minimum(refPDF, genPDF), x_vals)
    print(f"Überlappende Fläche der beiden Dichtefunktionen bei {feature}: {overlap_area}")
    return overlap_area

def normDTW(refJson,genJson,feature):
    from dtaidistance import dtw
    import numpy as np
    import matplotlib.pyplot as plt
    ### Zeitreihen erstellen
    refSamples = []
    for block in refJson["sequence"]:
        if block["type"] == "p":
            refSamples += [0] * ((int)(block["data"]["dur"]))
        else:
            refSamples += [block["data"][feature]]*((int)(block["data"]["dur"]))

    genSamples = []
    for block in genJson["sequence"]:
        if block["type"] == "p":
            genSamples += [0] * ((int)(block["data"]["dur"]))
        else:
            genSamples += [block["data"][feature]]*((int)(block["data"]["dur"]))
    
    # Normalisierten
    genMean=np.mean(genSamples)
    genSamples= [value - genMean for value in genSamples]

    refMean=np.mean(refSamples)
    refSamples= [value - refMean for value in refSamples]

    # plt.figure()
    # plt.title("DTW")
    # plt.plot(genSamples)
    # plt.plot(refSamples)

    #dtw
    distance = dtw.distance(refSamples,genSamples)
    print(f"Die DTW Distanz beträgt bei {feature} {distance}")
    return distance


    

def calcMetrics(refJson,genJson,results):
    #TODO
    if "compareDistribution" not in results:
        results["compareDistribution"] = {"freq": [], "amp": [], "dur": []}
        results["distance"] = {"freq":[], "amp":[]}
    for feature in results["compareDistribution"]:
        results["compareDistribution"][feature].append(compareDistribution(refJson,genJson,feature))
    for feature in results["distance"]:
        results["distance"][feature].append(normDTW(refJson,genJson,feature))

# %%
import json
import numpy

path = r"C:\Users\Domin\Desktop\testNr3_v3_tests.json"

endOfText="<|end_of_text|>"

with open(path, "r") as f:
    modelletests = json.load(f)

allTestsResults = {}
for tests in modelletests:
    results = {}
    for i, dataset in enumerate(modelletests[tests]):

        print("\n\n\n\nDatensatz",i)
        print("Prompt:",dataset["prompt"])
        print("Testdaten:")
        referenceData=findResponse(dataset["referenceData"])
        referenceData= referenceData[:-len(endOfText)]
        refJson = json.loads(referenceData)

        ID = f"Data{i}"
        VERSION = 0

        #visualize(refJson)
        # calcMetrics(refJson)


        for j, data in enumerate(dataset["generatedData"]):


            VERSION = j+1

            response=findResponse(data)
            print(response)
            ojson=fixUnfinishedJson(response)
            print(f"Generierung {j}:")


            #visualize(ojson)

            calcMetrics(refJson,ojson, results)

    allTestsResults[tests] = results
import numpy as np
import matplotlib.pyplot as plt

for model in allTestsResults:
    print("## Auswertung")
    for key in allTestsResults[model]:
        for feature in allTestsResults[model][key]:
            print("Modell:", model)
            print(f"Metrik:{key} Durchschnitt von {feature}: {np.mean(allTestsResults[model][key][feature])}")
            print(f"Metrik:{key} Standartabweichung von {feature}: {np.std(allTestsResults[model][key][feature])}")

allTestsTesultsPerMerrik = {}
allTestsLabels = []
for model in allTestsResults:
    for key in allTestsResults[model]:
        for feature in allTestsResults[model][key]:

            if key not in allTestsTesultsPerMerrik:
                allTestsTesultsPerMerrik[key] = {}
            if feature not in allTestsTesultsPerMerrik[key]:
                allTestsTesultsPerMerrik[key][feature] = []
            
            allTestsTesultsPerMerrik[key][feature].append(allTestsResults[model][key][feature])
    allTestsLabels.append(model)

print("Labels", allTestsLabels)
print("allTestsTesultsPerMerrik",allTestsTesultsPerMerrik)      

for key in allTestsTesultsPerMerrik:
    for feature in allTestsTesultsPerMerrik[key]:
        moreOreLessIsBetter = ""
        if key == "distance": moreOreLessIsBetter="(Weniger ist besser)"
        else: moreOreLessIsBetter="(Mehr ist besser)"
        plt.figure()
        plt.title(f"Metrik: {key}, Box-Plot für: {feature} {moreOreLessIsBetter}")
        plt.boxplot(allTestsTesultsPerMerrik[key][feature],showmeans=True, meanline=True)
        plt.xticks([i + 1 for i in range(len(allTestsLabels))], allTestsLabels)
# Out:
# Datensatz 0
# Prompt:
# Create a regular, smooth, discontinuous, and soft vibrotactile pattern. This pattern should evoke a calm, comfortable, natural, predictable, and familiar feeling, reminiscent of a heartbeat, pawing, an animal, or gentle tapping. Use this pattern to signal a reminder, indicate a low battery, or prompt the user to slow down.
#
#
# Testdaten:
#
# {"sequence": [{"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.1, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.14, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.2, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.28, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.36, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.44, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.52, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.59, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.71, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.77, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.84, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.9, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.98, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.98, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.8, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.73, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.56, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.46, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.23, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.11, "freq": 131, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.1, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.14, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.2, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.28, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.36, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.44, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.52, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.59, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.71, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.77, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.84, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.9, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.98, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.99, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.98, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 131, "form": "sine", "dur": 26}}, {"type": "v", "data": ...
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.11035204863108909
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.6948223067252266
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0009122490752141303
# Die DTW Distanz beträgt bei freq 2344.383721156651
# Die DTW Distanz beträgt bei amp 16.263337129686512
#
# {"sequence": [{"type": "p", "data": {"dur": 68}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.1, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v", "data": {"amp": 0.09, "freq": 93, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 42}}, {"type": "v" ...
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.434456945162639
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.11515447583827253
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.08599668656199548
# Die DTW Distanz beträgt bei freq 3579.307696993455
# Die DTW Distanz beträgt bei amp 14.096608576733932
#
# {"sequence": [{"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 98, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 5 ...
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.40349956569560536
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.16136912666774444
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.11253969755594334
# Die DTW Distanz beträgt bei freq 3853.026935504755
# Die DTW Distanz beträgt bei amp 13.38117115333386
#
# {"sequence": [{"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.2, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sine", "dur": 30}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sine", "dur": 30}}, {"type": "v", "data": {"amp": 0.2, "freq": 116, "form": "sine", "dur": 28}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.2, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sine", "dur": 30}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sine", "dur": 30}}, {"type": "v", "data": {"amp": 0.2, "freq": 116, "form": "sine", "dur": 28}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.2, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sine", "dur": 30}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.91, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 116, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.61, "freq": 116, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.46, "freq": 116, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.31, "freq": 116, "form": "sin ...
# Generierung 3:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.25605104033344883
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.6652611161404427
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.07168320344045225
# Die DTW Distanz beträgt bei freq 2504.964847600302
# Die DTW Distanz beträgt bei amp 15.110735307990735
#
# {"sequence": [{"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.11, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.15, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.2, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.25, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.29, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.3, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.3, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.29, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.25, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.2, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.15, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.11, "freq": 127, "form": "sine", "dur": 28}}, {"type": "p", "data": {"dur": 50}}]}
# Generierung 4:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.34633525348529975
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.28792279606883336
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.11156097555436156
# Die DTW Distanz beträgt bei freq 2811.2362559083626
# Die DTW Distanz beträgt bei amp 15.309336763961303
#
#
#
#
# Datensatz 1
# Prompt:
# Design a vibrotactile pattern that feels smooth, complex, dynamic, bumpy, and irregular, evoking a unique, rhythmic, comfortable, happy, interesting, lively, and pleasant sensation, like an engine, suitable for encouragement, milestones, or congratulations.
#
#
# Testdaten:
#
# {"sequence": [{"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.25, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.45, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.55, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.85, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.85, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.55, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.45, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.25, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.15, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.05, "freq": 152, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.25, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.45, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.55, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.85, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.85, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.75, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.65, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.55, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.45, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.25, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.15, "freq": 152, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.05, "freq": 152, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 26}}]}
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.44394046962866385
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.8319237114852045
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0014795939487523527
# Die DTW Distanz beträgt bei freq 1747.630181436696
# Die DTW Distanz beträgt bei amp 10.476393757747756
#
# {"sequence": [{"type": "p", "data": {"dur": 58}}, {"type": "v", "data": {"amp": 0.05, "freq": 127, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.16, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.26, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.35, "freq": 127, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.42, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.49, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.56, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.62, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.67, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.72, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.77, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.81, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.84, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.86, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.87, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.87, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.86, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.84, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.81, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.77, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.72, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.67, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.62, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.56, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.49, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.42, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.35, "freq": 127, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.26, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.16, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.05, "freq": 127, "form": "sine", "dur": 32}}, {"type": "p", "data": {"dur": 58}}, {"type": "v", "data": {"amp": 0.05, "freq": 127, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.16, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.26, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.35, "freq": 127, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.42, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.49, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.56, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.62, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.67, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.72, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.77, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.81, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.84, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.86, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.87, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.87, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.86, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.84, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.81, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v", "data": {"amp": 0.77, "freq": 127, "form": "sine", "dur": 28}}, {"type": "v",  ...
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.45261132623757044
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.7937366867013642
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.06889506921410996
# Die DTW Distanz beträgt bei freq 1905.9031767013535
# Die DTW Distanz beträgt bei amp 10.202640382570875
#
# {"sequence": [{"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.17, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.37, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.57, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.77, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.97, "freq": 139, "form": "sine", "dur": 27}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.17, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.37, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.57, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.77, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.97, "freq": 139, "form": "sine", "dur": 27}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.17, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.37, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.57, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.77, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.97, "freq": 139, "form": "sine", "dur": 27}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.17, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.37, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.57, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.77, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.97, "freq": 139, "form": "sine", "dur": 27}}, {"type": "p", "data": {"dur": 26}}, {"type": "v", "data": {"amp": 0.17, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.37, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.57, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.77, "freq": 139, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.97, "freq": 139, "form": "sine", "dur": 27}}, {"type": "p", "data": {"dur": 26}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.6252028298453016
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.75619046230046
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0074181473162710345
# Die DTW Distanz beträgt bei freq 2005.1504433081925
# Die DTW Distanz beträgt bei amp 7.410611114988493
#
# {"sequence": [{"type": "p", "data": {"dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 155, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, "form": "sine", "dur": 32}}, {"type": "v", "data": {"amp": 0.95, "freq": 154, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.92, "freq": 154, " ...
# Generierung 3:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.18152516627595064
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.13010652173189224
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0317629349956781
# Die DTW Distanz beträgt bei freq 1534.6974163721932
# Die DTW Distanz beträgt bei amp 13.041037513683762
#
# {"sequence": [{"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.97, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.94, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.9, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.86, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.81, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.75, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.69, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.63, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.58, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.52, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.46, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.4, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.35, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.3, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.25, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.2, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.15, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.11, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.08, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.06, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.04, "freq": 98, "form": "sine", "dur": 50}}, {"type": "v", "data": {"amp": 0.02, "freq": 98, "form": "sine", "dur": 50}}, {"type": "p", "data": {"dur": 50}}]}
# Generierung 4:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.4609956860625255
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.7301918928610858
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0
# Die DTW Distanz beträgt bei freq 1528.3000955046075
# Die DTW Distanz beträgt bei amp 14.8370784234248
#
#
#
#
# Datensatz 2
# Prompt:
# Design a smooth and regular vibration with a soft, ramping-down effect that evokes a calm, pleasant, comfortable, and natural feeling, similar to the fading sound of a musical instrument like drums, an echo, or a bell. This vibration would be appropriate for notifications such as low battery, interval/rep markers, warnings, signals for falling below an intended threshold, get ready cues, resume commands, or confirmations.
#
#
# Testdaten:
#
# {"sequence": [{"type": "p", "data": {"dur": 30}}, {"type": "v", "data": {"amp": 0.09, "freq": 91, "form": "sine", "dur": 101}}, {"type": "v", "data": {"amp": 0.16, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.23, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.3, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.37, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.44, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.51, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.58, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.65, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.72, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.79, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.86, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.93, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 0.99, "freq": 91, "form": "sine", "dur": 100}}, {"type": "v", "data": {"amp": 1.0, "freq": 91, "form": "sine", "dur": 99}}]}
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.406193175352057
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.7019298874578054
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.14152972034297745
# Die DTW Distanz beträgt bei freq 1850.8096519477472
# Die DTW Distanz beträgt bei amp 17.551648471276913
#
# {"sequence": [{"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 29}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": "v", "data": {"amp": 0.91, "freq": 127, "form": "sine", "dur": 27}}, {"type": ...
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.0004678978557932758
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.00040164621329540686
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.0005877979838428305
# Die DTW Distanz beträgt bei freq 2122.6839259438684
# Die DTW Distanz beträgt bei amp 12.340624264032034
#
# {"sequence": [{"type": "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.09, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.26, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.44, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.64, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.83, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.93, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.95, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.94, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.92, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.89, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.86, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.83, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.8, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.77, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.73, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.7, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.66, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.62, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.59, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.55, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.51, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.47, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.43, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.39, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.35, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.31, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.27, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.23, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.19, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.15, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.11, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.07, "freq": 175, "form": "sine", "dur": 26}}, {"type": "v", "data": {"amp": 0.03, "freq": 175, "form": "sine", "dur": 26}}, {"type": "p", "data": {"dur": 26}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.10955611175602717
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.6945015507867406
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.028819430686038323
# Die DTW Distanz beträgt bei freq 1924.599339657222
# Die DTW Distanz beträgt bei amp 4.950357164676509
#
# ...
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.2837880290468059
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5707461234365578
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.6068983205559532
# Die DTW Distanz beträgt bei freq 3500.150077173035
# Die DTW Distanz beträgt bei amp 11.044045759592041
# {"sequence": [{"type": "v", "data": {"amp": 0.85, "freq": 120, "dur": 150}}, {"type": "p", "data": {"dur": 30}}, {"type": "v", "data": {"amp": 0.9, "freq": 250, "dur": 100}}, {"type": "p", "data": {"dur": 25}}, {"type": "v", "data": {"amp": 0.8, "freq": 400, "dur": 130}}, {"type": "p", "data": {"dur": 20}}, {"type": "v", "data": {"amp": 0.95, "freq": 350, "dur": 110}}, {"type": "p", "data": {"dur": 35}}, {"type": "v", "data": {"amp": 0.7, "freq": 220, "dur": 80}}, {"type": "p", "data": {"dur": 28}}, {"type": "v", "data": {"amp": 0.85, "freq": 180, "dur": 140}}, {"type": "p", "data": {"dur": 25}}, {"type": "v", "data": {"amp": 0.9, "freq": 270, "dur": 100}}]}
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.26225296161893025
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5973387045910589
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.5367337385531789
# Die DTW Distanz beträgt bei freq 3659.4242184610607
# Die DTW Distanz beträgt bei amp 11.122064683230498
# {"sequence": [{"type": "p", "data": {"dur": 13}}, {"type": "v", "data": {"amp": 0.98, "freq": 220, "form": "sine", "dur": 115}}, {"type": "p", "data": {"dur": 11}}, {"type": "v", "data": {"amp": 1.0, "freq": 300, "form": "sine", "dur": 65}}, {"type": "p", "data": {"dur": 23}}, {"type": "v", "data": {"amp": 0.97, "freq": 400, "form": "sine", "dur": 90}}, {"type": "p", "data": {"dur": 15}}, {"type": "v", "data": {"amp": 0.99, "freq": 250, "form": "sine", "dur": 120}}, {"type": "p", "data": {"dur": 20}}, {"type": "v", "data": {"amp": 1.0, "freq": 350, "form": "sine", "dur": 100}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.22333962554060893
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5004077074951111
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.5211129335814554
# Die DTW Distanz beträgt bei freq 2905.8326501587044
# Die DTW Distanz beträgt bei amp 9.851205906913822
#
#
#
#
# Datensatz 1
# Prompt:
# Generate a discontinuous, grainy, regular, spiky, and bumpy vibration with a simple quality that creates a happy, lively, energetic, comfortable, pleasant, mechanical, and rhythmic sensation, similar to the feeling of a gun firing, an engine running, or an animal moving. This vibration could be used in a variety of applications where a unique and engaging tactile experience is desired, such as gaming feedback, interactive art installations, or haptic notifications for specific events or actions.
#
#
# Testdaten:
# {"sequence": [{"type": "v", "data": {"amp": 0.85, "freq": 320, "dur": 200}}, {"type": "p",
# "data": {"dur": 30}}, {"type": "v", "data": {"amp": 1.0, "freq": 100, "dur": 150}}, {"type": "p", "data":
# {"dur": 50}}, {"type": "v", "data": {"amp": 0.9, "freq": 240, "dur": 120}}, {"type": "p", "data": {"dur": 20}},
# {"type": "v", "data": {"amp": 1.2, "freq": 420, "dur": 300}}]}
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.5464532526468221
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5802072446250099
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.44097738222322236
# Die DTW Distanz beträgt bei freq 4841.412693898682
# Die DTW Distanz beträgt bei amp 11.732379559174682
# {"sequence": [{"type": "v", "data": {"amp": 0.8, "freq": 240, "dur": 150}}, {"type": "p", "data": {"dur": 30}},
# {"type": "v", "data": {"amp": 1.2, "freq": 420, "dur": 220}}, {"type": "p", "data": {"dur": 20}}, {"type": "v",
# "data": {"amp": 0.7, "freq": 150, "dur": 100}}, {"type": "p", "data": {"dur": 50}}]}
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.5151233562746339
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5727186310324095
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.5431540345153948
# Die DTW Distanz beträgt bei freq 3980.588858662396
# Die DTW Distanz beträgt bei amp 10.05057186806791
# {"sequence": [{"type": "p", "data": {"dur": 17}}, {"type": "v", "data": {"amp": 0.85, "freq": 320, "form":
# "sine", "dur": 61}}, {"type": "p", "data": {"dur": 14}}, {"type": "v", "data": {"amp": 1.0, "freq": 450, "form":
# "sine", "dur": 32}}, {"type": "p", "data": {"dur": 21}}, {"type": "v", "data": {"amp": 0.95, "freq": 190,
# "form": "sine", "dur": 43}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.5460781732632454
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5022298359698283
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.40506493934356536
# Die DTW Distanz beträgt bei freq 3125.9016665614704
# Die DTW Distanz beträgt bei amp 9.751825414757738
#
#
#
#
# Datensatz 2
# Prompt:
# Create a regular, smooth, discontinuous, and soft vibrotactile pattern. This pattern should evoke a calm, comfortable, natural, predictable, and familiar feeling, reminiscent of a heartbeat, pawing, an animal, or gentle tapping. Use this pattern to signal a reminder, indicate a low battery, or prompt the user to slow down.
#
#
# Testdaten:
# {"sequence": [{"type": "v", "data": {"amp": 0.7, "freq": 120, "dur": 150}}, {"type": "p",
# "data": {"dur": 20}}, {"type": "v", "data": {"amp": 0.6, "freq": 200, "dur": 100}}, {"type":
# "p", "data": {"dur": 30}}, {"type": "v", "data": {"amp": 1.0, "freq": 300, "dur": 50}}]}
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.30599706394260423
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.6154629387874071
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.4647780837819027
# Die DTW Distanz beträgt bei freq 3182.386738670903
# Die DTW Distanz beträgt bei amp 16.45721684299383
# {"sequence": [{"type": "p", "data": {"dur": 104}}, {"type": "v", "data": {"amp": 0.75, "freq":
# 40, "form": "sine", "dur": 200}}, {"type": "p", "data": {"dur": 50}}, {"type": "v", "data":
# {"amp": 0.85, "freq": 60, "form": "sine", "dur": 150}}, {"type": "p", "data": {"dur": 25}}]}
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.3574480194993233
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5560061650101048
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.5213468789283568
# Die DTW Distanz beträgt bei freq 2010.1159910590652
# Die DTW Distanz beträgt bei amp 21.506042426869538
# {"sequence": [{"type": "v", "data": {"amp": 0.8, "freq": 50, "dur": 150}}, {"type": "p", "data":
# {"dur": 100}}, {"type": "v", "data": {"amp": 1.0, "freq": 200, "dur": 300}}, {"type": "p",
# "data": {"dur": 50}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.3951996341408848
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5331007463074766
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.564117162864991
# Die DTW Distanz beträgt bei freq 4535.529986309627
# Die DTW Distanz beträgt bei amp 18.73493416608074
#
#
#
#
# Datensatz 3
# Prompt:
# Design a smooth and regular vibration with a soft, ramping-down effect that evokes a calm, pleasant, comfortable, and natural feeling, similar to the fading sound of a musical instrument like drums, an echo, or a bell. This vibration would be appropriate for notifications such as low battery, interval/rep markers, warnings, signals for falling below an intended threshold, get ready cues, resume commands, or confirmations.
#
#
# Testdaten:
# {"sequence": [{"type": "p", "data": {"dur": 18}}, {"type": "v", "data": {"amp": 0.8, "freq":
# 250, "form": "sine", "dur": 120}}, {"type": "p", "data": {"dur": 12}}, {"type": "v", "data":
# {"amp": 1.0, "freq": 450, "form": "square", "dur": 100}}, {"type": "p", "data": {"dur": 15}},
# {"type": "v", "data": {"amp": 0.7, "freq": 200, "form": "sawtooth", "dur": 80}}]}
# Generierung 0:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.28555665637273686
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5812029747586303
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.3143539978848947
# Die DTW Distanz beträgt bei freq 2651.6101579981046
# Die DTW Distanz beträgt bei amp 8.917277254128752
# {"sequence": [{"type": "v", "data": {"amp": 0.5, "freq": 200, "dur": 500}}, {"type": "p",
# "data": {"dur": 100}}, {"type": "v", "data": {"amp": 0.8, "freq": 300, "dur": 400}}, {"type":
# "p", "data": {"dur": 50}}, {"type": "v", "data": {"amp": 0.2, "freq": 100, "dur": 800}}]}
# Generierung 1:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.35365714310993573
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5064442244905193
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.5437896258835972
# Die DTW Distanz beträgt bei freq 3167.789940813253
# Die DTW Distanz beträgt bei amp 9.343815335952947
# {"sequence": [{"type": "v", "data": {"amp": 0.7, "freq": 200, "dur": 500}},{"type": "p", "data": {"dur": 50}},{"type": "v", "data": {"amp": 0.6, "freq": 150, "dur": 300}},{"type": "p", "data": {"dur": 20}},{"type": "v", "data": {"amp": 0.5, "freq": 100, "dur": 200}}]}
# Generierung 2:
# Überlappende Fläche der beiden Dichtefunktionen bei freq: 0.4399760680901368
# Überlappende Fläche der beiden Dichtefunktionen bei amp: 0.5717400105693451
# Überlappende Fläche der beiden Dichtefunktionen bei dur: 0.6149562815333569
# Die DTW Distanz beträgt bei freq 1862.881069105377
# Die DTW Distanz beträgt bei amp 10.159004608256533
# ## Auswertung
# Modell: Fine-Tuned-2-Epochen
# Metrik:compareDistribution Durchschnitt von freq: 0.2879574141375351
# Metrik:compareDistribution Standartabweichung von freq: 0.15965691829417838
# Modell: Fine-Tuned-2-Epochen
# Metrik:compareDistribution Durchschnitt von amp: 0.4673241949362243
# Metrik:compareDistribution Standartabweichung von amp: 0.2788322657700567
# Modell: Fine-Tuned-2-Epochen
# Metrik:compareDistribution Durchschnitt von dur: 0.05073266350853861
# Metrik:compareDistribution Standartabweichung von dur: 0.05427745382574031
# Modell: Fine-Tuned-2-Epochen
# Metrik:distance Durchschnitt von freq: 2886.204816404229
# Metrik:distance Standartabweichung von freq: 1450.0147134783062
# Modell: Fine-Tuned-2-Epochen
# Metrik:distance Durchschnitt von amp: 14.751863769811436
# Metrik:distance Standartabweichung von amp: 6.828392410832775
# ## Auswertung
# Modell: Fine-Tuned-10-Epochen
# Metrik:compareDistribution Durchschnitt von freq: 0.4553598944856313
# Metrik:compareDistribution Standartabweichung von freq: 0.20797194250421008
# Modell: Fine-Tuned-10-Epochen
# Metrik:compareDistribution Durchschnitt von amp: 0.5303961494739512
# Metrik:compareDistribution Standartabweichung von amp: 0.15779728500993553
# Modell: Fine-Tuned-10-Epochen
# Metrik:compareDistribution Durchschnitt von dur: 0.35055005088168567
# Metrik:compareDistribution Standartabweichung von dur: 0.13670034897948097
# Modell: Fine-Tuned-10-Epochen
# Metrik:distance Durchschnitt von freq: 2485.5279577059537
# Metrik:distance Standartabweichung von freq: 1091.8754056497116
# Modell: Fine-Tuned-10-Epochen
# Metrik:distance Durchschnitt von amp: 11.227706294448424
# Metrik:distance Standartabweichung von amp: 5.642516852027295
# ## Auswertung
# Modell: One-Shot
# Metrik:compareDistribution Durchschnitt von freq: 0.3762391652955557
# Metrik:compareDistribution Standartabweichung von freq: 0.1081925353300688
# Modell: One-Shot
# Metrik:compareDistribution Durchschnitt von amp: 0.5573004422561216
# Metrik:compareDistribution Standartabweichung von amp: 0.03668811046887748
# Modell: One-Shot
# Metrik:compareDistribution Durchschnitt von dur: 0.5064402816374891
# Metrik:compareDistribution Standartabweichung von dur: 0.08290931434485396
# Modell: One-Shot
# Metrik:distance Durchschnitt von freq: 3285.30200407264
# Metrik:distance Standartabweichung von freq: 861.1452431385142
# Modell: One-Shot
# Metrik:distance Durchschnitt von amp: 12.389198652168252
# Metrik:distance Standartabweichung von amp: 3.9680928559397586
# Labels ['Fine-Tuned-2-Epochen', 'Fine-Tuned-10-Epochen', 'One-Shot']
# allTestsTesultsPerMerrik {'compareDistribution': {'freq': [[0.11035204863108909, 0.434456945162639, 0.40349956569560536, 0.25605104033344883, 0.34633525348529975, 0.44394046962866385, 0.45261132623757044, 0.6252028298453016, 0.18152516627595064, 0.4609956860625255, 0.406193175352057, 0.0004678978557932758, 0.10955611175602717, 0.32161836626313034, 0.1816453014523992, 0.03423833129816998, 0.2770855050490404, 0.12482358307212278, 0.27842541466069515, 0.31012426463317255], [0.6925388612264562, 0.7662742678229012, 0.7311684376566944, 0.41843319330821604, 0.7270087079486227, 0.07953722341414454, 0.3361672513527437, 0.4514113972897057, 0.17896267497281917, 0.18266039816112487, 0.5442198655341836, 0.5442198655341836, 0.36494146665827465, 0.5442198655341836, 0.5442198655341836, 0.6187228470178165, 0.45724535776354003, 0.5944049006873995, 0.14594612931304202, 0.18489531298239145], [0.2837880290468059, 0.26225296161893025, 0.22333962554060893, 0.5464532526468221, 0.5151233562746339, 0.5460781732632454, 0.30599706394260423, 0.3574480194993233, 0.3951996341408848, 0.28555665637273686, 0.35365714310993573, 0.4399760680901368]], 'amp': [[0.6948223067252266, 0.11515447583827253, 0.16136912666774444, 0.6652611161404427, 0.28792279606883336, 0.8319237114852045, 0.7937366867013642, 0.75619046230046, 0.13010652173189224, 0.7301918928610858, 0.7019298874578054, 0.00040164621329540686, 0.6945015507867406, 0.7151218018159025, 0.1417861733866105, 0.022780983410042817, 0.5135322045483042, 0.5684870041724577, 0.41063177520639993, 0.41063177520639993], [0.7925410089864032, 0.7313250978487363, 0.7672380671597602, 0.3186758764808308, 0.7875533087763396, 0.4334239359624975, 0.4998892633144066, 0.402725687698322, 0.40321416395524423, 0.5271393637407151, 0.340210276886389, 0.34086099890841776, 0.5229312127945647, 0.340210276886389, 0.340210276886389, 0.6179789348457029, 0.5811301538621846, 0.6250166133592711, 0.6233774592191901, 0.6122710119072698], [0.5707461234365578, 0.5973387045910589, 0.5004077074951111, 0.5802072446250099, 0.5727186310324095, 0.5022298359698283, 0.6154629387874071, 0.5560061650101048, 0.5331007463074766, 0.5812029747586303, 0.5064442244905193, 0.5717400105693451]], 'dur': [[0.0009122490752141303, 0.08599668656199548, 0.11253969755594334, 0.07168320344045225, 0.11156097555436156, 0.0014795939487523527, 0.06889506921410996, 0.0074181473162710345, 0.0317629349956781, 0.0, 0.14152972034297745, 0.0005877979838428305, 0.028819430686038323, 0.19320506149936806, 0.0, 0.03676124165253582, 0.06358246219450302, 0.05791899814872862, 0.0, 0.0], [0.41606629720121846, 0.05112329837757126, 0.5040758018978304, 0.5560216207516123, 0.37660221032497065, 0.30631484608330256, 0.37640838406573973, 0.5104699879481465, 0.5108190832342241, 0.16787162281495488, 0.415835327322998, 0.4488792688775179, 0.18242155224609533, 0.41269497854458265, 0.42376363489145147, 0.386623041931374, 0.21058614229111347, 0.1457282467729605, 0.24297391671225002, 0.3657217553437999], [0.6068983205559532, 0.5367337385531789, 0.5211129335814554, 0.44097738222322236, 0.5431540345153948, 0.40506493934356536, 0.4647780837819027, 0.5213468789283568, 0.564117162864991, 0.3143539978848947, 0.5437896258835972, 0.6149562815333569]]}, 'distance': {'freq': [[2344.383721156651, 3579.307696993455, 3853.026935504755, 2504.964847600302, 2811.2362559083626, 1747.630181436696, 1905.9031767013535, 2005.1504433081925, 1534.6974163721932, 1528.3000955046075, 1850.8096519477472, 2122.6839259438684, 1924.599339657222, 4084.294494574606, 2395.4230173486467, 2810.56162409684, 2727.003746440267, 2617.4046329302796, 6360.428286784636, 7016.286837873903], [5003.020110185884, 1058.3328455870574, 1663.2730395899039, 2130.0876218351377, 2118.6618590454063, 2697.0523579578316, 3540.613932429952, 4263.323715745531, 2449.13379364394, 4685.427129617337, 2639.07198970985, 2138.1916805605824, 1904.7729672358153, 2639.1129447863564, 2640.4354270499557, 1727.1661581132448, 681.9315441484653, 1994.6154170171546, 1789.58408 ...

# %% [markdown]
# # Graphen generieren

# %%
# path = r"C:\Users\Domin\OneDrive\HTW\Bachelorarbeit\one-shot-instructed.json"
# with open(path, "r") as f:
#     generatoins = json.load(f)

# for i,data in enumerate(generatoins):
#     print(data)
#     ID = i
#     if i%3 == 0:
#         continue
#     visualize(data)
